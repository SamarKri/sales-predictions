# %% [markdown]
# # **PROJECT 1 - FINAL**
# *   Samar KRIMI
# *   15/08/2023
# ---

# %% [markdown]
# # **Part 1**

# %%
# Import the data as a Pandas DataFrame
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data 'sales_predictions_2023.csv'
filename = '/content/sales_predictions_2023.csv'

# %%
# Read data
df = pd.read_csv(filename)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
# The top 5 rows of the dataframe
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# # **Part 2**

# %%
# Examine the number of unique values in columns
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %% [markdown]
# **Question 1 :** How many rows and columns

# %%
# Obtain essential information about the data : check columns, rows, data types, and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# *   8523 rows and 12 columns

# %% [markdown]
# **Question 2 :** The datatypes of each variable

# %%
# Get the data type for all columns
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# *   7 objects, 4 floats, 1 integer

# %% [markdown]
# **Question 3  :** Find any duplicates and drop them

# %%
# Find duplicated
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
# check duplicated data
df.duplicated().any()
# Out:
# False

# %%
# Count the duplicates
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# *   there is no duplicated data

# %% [markdown]
# **Question 4 :** Identify missing values

# %%
# Check the df to see if there are missing values : Sums the number of nas in each column
#df.isna().sum()
null_vals=df.isna().sum()
null_vals
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# *  For variable Item_Weight there are 1463 nas (8523-7060)
# *  For variable Outlet_Size there are 2410 nas (8523-6113)

# %% [markdown]
# **Question 5 & 6 :** Decide on how to address the missing values & Confirm that there are no missing values after addressing them

# %%
# Check the Item_Weight column
df['Item_Weight'].value_counts()
# Out:
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: Item_Weight, Length: 415, dtype: int64

# %%
# check the mean value of Item_Weight variable
df[['Item_Weight']].mean()
# Out:
# Item_Weight    12.857645
# dtype: float64

# %%
# Imputing Missing Data of Item_Weight column by its mean value
df['Item_Weight'].fillna(value = 12.857, inplace = True)

# %%
# There are no missing values after addressing Item_Weight column
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Check the categorical values of Outlet_Size variable
df['Outlet_Size'].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
# Imputing Missing Data of Outlet_Size column by its categorical value equal to Medium
df['Outlet_Size'].fillna(value='Medium', inplace = True)

# %%
# There are no missing values after addressing Outlet_Size column
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# * Imputation with **mean value** for variable Item_Weight : it contains only values
# * Imputation with **Medium** for variable Outlet_Size : the most repetitive  category

# %% [markdown]
# **Question 7 :** Find and fix any inconsistent categories of data this can include misspellings, abbreviations or typos

# %%
# Get all datatypes
data_types = df.dtypes
data_types
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Get all object datatypes
str_cols = data_types[data_types=="object"]
str_cols
# Out:
# Item_Identifier         object
# Item_Fat_Content        object
# Item_Type               object
# Outlet_Identifier       object
# Outlet_Size             object
# Outlet_Location_Type    object
# Outlet_Type             object
# dtype: object

# %% [markdown]
# * There are 7 objects : Item_Identifier, Item_Fat_Content, Item_Type, Outlet_Identifier, Outlet_Size, Outlet_Location_Type, Outlet_Type

# %%
# We use .value_counts() to examine Item_Identifier column
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
# We use .value_counts() to examine Item_Fat_Content column
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
# Inconsistent categories of data from Item_Fat_Content column are fixed
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace(['LF', 'low fat','reg'],['Low Fat','Low Fat','Regular'])
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# * Inconsistent categories of data from Item_Fat_Content are fixed : LF and low fat are replaced by Low Fat and reg is replaced by Regular

# %%
# We use .value_counts() to examine Item_Type column
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %% [markdown]
# * Household and Health and Hygiene are unrelated to Item_type column that
# describes the category to which the product belongs there must be replaced by others

# %%
#  Inconsistent categories of data from Item_Type column are fixed
df['Item_Type'] = df['Item_Type'].replace(['Household', 'Health and Hygiene'],['Others','Others'])
df['Item_Type'].value_counts()
# Out:
# Others                   1599
# Fruits and Vegetables    1232
# Snack Foods              1200
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
# We use .value_counts() to examine Outlet_Identifier column
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
# We use .value_counts() to examine Outlet_Size column
df['Outlet_Size'].value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
# We use .value_counts() to examine Outlet_Location_Type column
df['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
# We use .value_counts() to examine Outlet_Size column
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# **Question 8 :** Obtain the summary statistics of each numerical columns

# %%
# Get all float64 datatypes
data_types[data_types=="float64"]
# Out:
# Item_Weight          float64
# Item_Visibility      float64
# Item_MRP             float64
# Item_Outlet_Sales    float64
# dtype: object

# %%
# Get all int64 datatypes
data_types[data_types=="int64"]
# Out:
# Outlet_Establishment_Year    int64
# dtype: object

# %%
# Show summary stats for all numeric columns
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857534         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857000         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# find summary stats for each numerical column and round to two decimal places
df.describe().round(2)
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# count      8523.00          8523.00   8523.00                    8523.00
# mean         12.86             0.07    140.99                    1997.83
# std           4.23             0.05     62.28                       8.37
# min           4.56             0.00     31.29                    1985.00
# 25%           9.31             0.03     93.83                    1987.00
# 50%          12.86             0.05    143.01                    1999.00
# 75%          16.00             0.09    185.64                    2004.00
# max          21.35             0.33    266.89                    2009.00
#
#        Item_Outlet_Sales
# count            8523.00
# mean             2181.29
# std              1706.50
# min                33.29
# 25%               834.25
# 50%              1794.33
# 75%              3101.30
# max             13086.96

# %%
# To View if there's a space in the columns name, no inconsistence in this categorial feature
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# # **Part 3**

# %%
# Get a random set of the dataframe cleaned
df.sample(30)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2205           FDD56       15.200          Regular         0.104201
# 1606           FDG02        7.855          Low Fat         0.011261
# 1144           FDB34       15.250          Low Fat         0.044539
# 4010           FDJ21       16.700          Regular         0.038528
# 6875           DRG37       12.857          Low Fat         0.033929
# 534            FDB53       13.350          Low Fat         0.140241
# 4860           FDP57       17.500          Low Fat         0.052550
# 2390           FDS44       12.650          Regular         0.156044
# 2245           FDH09       12.600          Low Fat         0.056395
# 3410           FDK40        7.035          Low Fat         0.021849
# 6259           FDC46       17.700          Low Fat         0.117202
# 1184           FDV44        8.365          Regular         0.039906
# 4118           NCP53       14.750          Low Fat         0.033024
# 8378           NCX05       15.200          Low Fat         0.097611
# 6331           FDA38        5.440          Low Fat         0.025459
# 6293           FDA22       12.857          Low Fat         0.000000
# 4839           FDB36       12.857          Regular         0.048292
# 4819           FDX21        7.050          Low Fat         0.084966
# 435            DRI13       15.350          Low Fat         0.020310
# 3479           FDA13       15.850          Low Fat         0.078490
# 7162           FDG08       13.150          Regular         0.165616
# 7607           FDY49       17.200          Regular         0.012080
# 7041           FDH35       18.250          Low Fat         0.060342
# 1269           FDD34        7.945          Low Fat         0.015908
# 7023           NCC19        6.570          Low Fat         0.096881
# 2604           FDT13       14.850          Low Fat         0.018677
# 2190           FDW13        8.500          Low Fat         0.098283
# 7430           NCO42       21.250          Low Fat         0.024694
# 2183           DRE15       13.350          Low Fat         0.017858
# 4247           NCG19       20.250          Low Fat         0.148164
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 2205  Fruits and Vegetables  176.5054            OUT018
# 1606                 Canned  189.5188            OUT046
# 1144            Snack Foods   85.3198            OUT010
# 4010            Snack Foods  143.9102            OUT046
# 6875            Soft Drinks  154.3972            OUT019
# 534            Frozen Foods  150.2392            OUT017
# 4860            Snack Foods  101.2990            OUT045
# 2390  Fruits and Vegetables  239.6538            OUT046
# 2245                Seafood   51.3982            OUT017
# 3410           Frozen Foods  262.0910            OUT046
# 6259            Snack Foods  184.0266            OUT017
# 1184  Fruits and Vegetables  191.3188            OUT049
# 4118                 Others  236.6906            OUT018
# 8378                 Others  116.5492            OUT017
# 6331                  Dairy  241.2538            OUT013
# 6293          Starchy Foods  167.5158            OUT027
# 4839           Baking Goods  133.1626            OUT027
# 4819            Snack Foods  111.1912            OUT046
# 435             Soft Drinks  218.0508            OUT013
# 3479                 Canned   39.9506            OUT013
# 7162  Fruits and Vegetables  172.6764            OUT049
# 7607                 Canned  164.4184            OUT017
# 7041          Starchy Foods  165.9526            OUT049
# 1269            Snack Foods  161.4210            OUT045
# 7023                 Others  191.4820            OUT046
# 2604                 Canned  188.7214            OUT017
# 2190                 Canned   51.3324            OUT018
# 7430                 Others  144.1102            OUT049
# 2183                  Dairy   77.5012            OUT018
# 4247                 Others  232.7616            OUT049
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 2205                       2009      Medium               Tier 3
# 1606                       1997       Small               Tier 1
# 1144                       1998      Medium               Tier 3
# 4010                       1997       Small               Tier 1
# 6875                       1985       Small               Tier 1
# 534                        2007      Medium               Tier 2
# 4860                       2002      Medium               Tier 2
# 2390                       1997       Small               Tier 1
# 2245                       2007      Medium               Tier 2
# 3410                       1997       Small               Tier 1
# 6259                       2007      Medium               Tier 2
# 1184                       1999      Medium               Tier 1
# 4118                       2009      Medium               Tier 3
# 8378                       2007      Medium               Tier 2
# 6331                       1987        High               Tier 3
# 6293                       1985      Medium               Tier 3
# 4839                       1985      Medium               Tier 3
# 4819                       1997       Small               Tier 1
# 435                        1987        High               Tier 3
# 3479                       1987        High               Tier 3
# 7162                       1999      Medium               Tier 1
# 7607                       2007      Medium               Tier 2
# 7041                       1999      Medium               Tier 1
# 1269                       2002      Medium               Tier 2
# 7023                       1997       Small               Tier 1
# 2604                       2007      Medium               Tier 2
# 2190                       2009      Medium               Tier 3
# 7430                       1999      Medium               Tier 1
# 2183                       2009      Medium               Tier 3
# 4247                       1999      Medium               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 2205  Supermarket Type2          2976.7918
# 1606  Supermarket Type1          1904.1880
# 1144      Grocery Store           261.6594
# 4010  Supermarket Type1          1749.7224
# 6875      Grocery Store           311.5944
# 534   Supermarket Type1          2684.5056
# 4860  Supermarket Type1           722.3930
# 2390  Supermarket Type1          3845.6608
# 2245  Supermarket Type1           473.3838
# 3410  Supermarket Type1          4207.8560
# 6259  Supermarket Type1          2397.5458
# 1184  Supermarket Type1          1713.7692
# 4118  Supermarket Type2          3089.9778
# 8378  Supermarket Type1           810.9444
# 6331  Supermarket Type1          3124.5994
# 6293  Supermarket Type3          4345.0108
# 4839  Supermarket Type3          2492.0894
# 4819  Supermarket Type1          1965.4416
# 435   Supermarket Type1          3038.7112
# 3479  Supermarket Type1           645.1602
# 7162  Supermarket Type1          2061.3168
# 7607  Supermarket Type1          2641.8944
# 7041  Supermarket Type1          1644.5260
# 1269  Supermarket Type1          3425.5410
# 7023  Supermarket Type1          5020.1320
# 2604  Supermarket Type1          3956.8494
# 2190  Supermarket Type2           934.7832
# 7430  Supermarket Type1          1749.7224
# 2183  Supermarket Type2          1518.0240
# 4247  Supermarket Type1          1874.8928

# %%
# Import the rest of librairies
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #  Explanatory Data Visualization

# %% [markdown]
# **Histogram to view the distributions of various features in the dataset**

# %%
#Create a histogram of a continuous variable: Item_Outlet_Sales
df['Item_Outlet_Sales'].hist(bins=30, edgecolor='black')
#Set the label of the x axis
plt.xlabel('Prices')
#Set the label of the y axis
plt.ylabel('Count')
#Give it a title
plt.title('Item_Outlet_Sales Distribution')
plt.show()

# %% [markdown]
# * The Item_Outlet_Sales Distribution dramatically decreases with greater prices

# %% [markdown]
# **Boxplot to view statistical summaries of various features in the dataset**

# %%
# Make multivariate boxplot graph to compare the distribution of Item_Visibility by Outlet_Size
sns.boxplot(data=df, x='Item_Visibility', y='Outlet_Size')
plt.show()

# %% [markdown]
# * The High Outlet_Size has the fewest outliers values while Medium and Small have more futher outliers around maximum
# * The mean values is near the middle of each box this is why he distribution is not skewed

# %% [markdown]
# **Heatmap of the correlation between features**

# %%
# Create a heatmap to show any potential correlations in this dataframe
corr_df = df.corr()
corr_df
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.012054  0.024757
# Item_Visibility              -0.012054         1.000000 -0.001315
# Item_MRP                      0.024757        -0.001315  1.000000
# Outlet_Establishment_Year    -0.008261        -0.074834  0.005020
# Item_Outlet_Sales             0.011545        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.008261           0.011545
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
ax = sns.heatmap(corr_df,
            cmap = sns.diverging_palette(240, 10, n=9), annot = True);

# %% [markdown]
# * Each numerical column is compared to the other.  When a column is compared with itself, it is always a perfect correlation which is why we see the values of 1 for : Item_Weight with Item_Weight, Item_Visibility with Item_Visibility, Item_MRP with Item_MRP, Outlet_Establishment_Year with Outlet_Establishment_Year & Item_Outlet_Sales with Item_Outlet_Sales.
# * Item_MRP with Item_Outlet_Sales has a moderate correlation equal to 0.57
# * The rest Item and outlet have a very low correlation between them

# %% [markdown]
# # **Part 4**

# %% [markdown]
# # Explanatory data analysis to focus on trends

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4                 Others   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# **Scatterplot with Seaborn**

# %%
# Seaborn scatter plot of Item_Visibility & Item_Outlet_Sales based on Item_Fat_Content
sns.scatterplot(data=df, x='Item_Visibility', y='Item_Outlet_Sales', hue='Item_Fat_Content');

# %% [markdown]
# It was a positive correlation between Item_Visibility & Item_Outlet_Sales variables : they decrease simultaneously.
# If Low Fat Items & Regular Fat Items are enough visible in a store they have more chance to be saled. Their visibility should be improved by storage or by changing the packaging or by advertising more to attract the buyer's attention.

# %%
# Seaborn scatter plot of Item_Visibility & Item_Outlet_Sales based on Outlet_Type
sns.scatterplot(data=df, x='Item_Visibility', y='Item_Outlet_Sales', hue='Outlet_Type');

# %% [markdown]
# In the grocery store the Item visibility increases however prices are very low maybe because consumers are not interested in these products types, Supermarket Type 3 has average visibility but sales are up maybe its products are fresher or makes interesting promotions.
# Supermarket Type 2 seems having the most reasonable sale and visibility Items, this type of supermarket should be used to improve outlet sales maybe by integrating a more dynamic staff.

# %% [markdown]
# **Bar Chart with Seaborn**

# %%
# Group Item_Outlet_Sales by Item_Type with specific order
avg = df.groupby('Item_Type')['Item_Outlet_Sales'].mean().sort_values(ascending=True).index
# plot a bar chart of Item_Outlet_Sales grouped by Item_Type
sns.barplot(data=df, x= 'Item_Outlet_Sales', y='Item_Type', order=avg)
# Set titles
plt.title('Average outlet sales by product category', fontsize = 14, fontweight='bold');
plt.xlabel('Item_Outlet_Sales', fontsize = 12, fontweight='bold');
plt.ylabel('Item_Type', fontsize = 12, fontweight='bold');

# %% [markdown]
# In order to help the retailer understand the properties of products and outlets that play crucial roles in increasing sales, we note that:
# Seafood & Starchy Food are the best-selling they are rich in carbohydrates, nutrients, fiber and vitamins, they are a real source of energy for the body. Thus, it brings energy to brain and muscles. They are ideal for physical and mental activities.
# in second order are Fruits and Vegetables & Snack Foods which are the most consumed by most people and thirdly Dairy, Canned & Breads.
# Baking Goods & Soft Drinks are the least sold, may be retailer must change their places in the store and I think that they are not recommended for people with certain diseases.

# %% [markdown]
# **Line graph**

# %%
# Group the dataframe by Outlet_Establishment_Year
line_df = df.groupby('Outlet_Establishment_Year').mean()
# Plot Line Graph of 'Item_MRP'&'Item_Outlet_Sales' grouped by Outlet_Establishment_Year
line_df.plot(y=['Item_MRP', 'Item_Outlet_Sales'], subplots=True, marker='o',figsize=(9,9), grid=True)
# Set title
plt.suptitle('Item_MRP & Item_Outlet_Sales Trends', fontsize=15, fontweight='bold', y=1);

# %% [markdown]
# Item_MRP trend seems very fluctuating over the year in which store was established.
# Firstly the list price of the product increase between 2000 & 2004 years, it falls sharply in 2008 maybe due to the financial crisis.
# Item_Outlet_Sales trend seems almost stable through these years but it falls very sharply in 1998, maybe some sales of certains products are out of stock or
# a particular store had an incident in this year.

# %% [markdown]
# # **Part 5**

# %%
# Import all librairies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_selector, ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# Set the default transformation output to pandas
from sklearn import set_config
set_config(transform_output='pandas')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Preprocesing for Machine Learning

# %%
# Explore data : no missing values, 3 nominal features, no ordinal features
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4                 Others   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998      Medium               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# Check dataframe types
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
# Check for total values for each type
df.dtypes.value_counts()
# Out:
# object     7
# float64    4
# int64      1
# dtype: int64

# %%
# Check for duplicated columns
df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
# Check for exact duplicates (rows)
# df.duplicated(subset = None, keep = 'first').sum()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Check any inconsistencies in categorical Features

# %%
# Identify string columns
string_cols = df.select_dtypes("object").columns
string_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
# Checking nuniuqe categories
df.select_dtypes('object').nunique()
# Out:
# Item_Identifier         1559
# Item_Fat_Content           2
# Item_Type                 14
# Outlet_Identifier         10
# Outlet_Size                3
# Outlet_Location_Type       3
# Outlet_Type                4
# dtype: int64

# %%
# Obtain the value counts for all string columns
for col in string_cols:
  print(f"Value Counts for {col}")
  print(df[col].value_counts())
  # Increasing readability by adding an empty line
  print('\n')
# Out:
# Value Counts for Item_Identifier
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64
#
#
# Value Counts for Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64
#
#
# Value Counts for Item_Type
# Others                   1599
# Fruits and Vegetables    1232
# Snack Foods              1200
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
# Value Counts for Outlet_Identifier
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64
#
#
# Value Counts for Outlet_Size
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
#
#
# Value Counts for Outlet_Location_Type
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
#
# Value Counts for Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
# Checking unique values in 'Item_Identifier' feature
df['Item_Identifier'].unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
# Check for cardinality of 'Item_Identifier' column
df['Item_Identifier'].nunique()
# Out:
# 1559

# %%
# Drop the 'Item_Identifier' column due to high cardinality
df.drop(columns = 'Item_Identifier', inplace = True)

# %%
# Checking unique values in 'Item_Fat_Content' feature => nominal feature
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
# Inconsistent categories of data from Item_Fat_Content column are fixed
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace(['Low Fat'],['Low'])
df['Item_Fat_Content'].value_counts()
# Out:
# Low        5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
# Checking unique values in 'Item_Type' feature => nominal feature
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables', 'Others',
#        'Baking Goods', 'Snack Foods', 'Frozen Foods', 'Breakfast',
#        'Hard Drinks', 'Canned', 'Breads', 'Starchy Foods', 'Seafood'],
#       dtype=object)

# %%
# Checking unique values in 'Outlet_Identifier' feature => nominal feature
df['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
# Checking unique values in 'Outlet_Establishment_Year' => I will convert it as object not integer
df['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004])

# %%
# The 'Outlet_Establishment_Year' column is an object => I will consider it nominal
# Convert the datatype of 'Outlet_Establishment_Year' from integer to 'object'
df['Outlet_Establishment_Year'] = df['Outlet_Establishment_Year'].astype('object')

# %%
# Checking unique values in 'Outlet_Identifier' feature => ordinal feature
df['Outlet_Size'].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
# Checking unique values in 'Outlet_Location_Type' feature => nominal feature
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
# Checking unique values in 'Outlet_Location_Type' feature => nominal feature
df['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %% [markdown]
# In final,
#
# There's 6 nominal features :'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Location_Type', 'Outlet_Type'.
#
# There's 1 ordinal feature :  'Outlet_Size'

# %% [markdown]
# * Check any inconsistencies in numeric Features

# %%
# Checking nuniuqe values sorted by ascending values
df.select_dtypes('number').nunique().sort_values()
# Out:
# Item_Weight           416
# Item_Outlet_Sales    3493
# Item_MRP             5938
# Item_Visibility      7880
# dtype: int64

# %%
# Checking for inconsistent numeric variables
description=df.describe().round(2)
description
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# count      8523.00          8523.00   8523.00            8523.00
# mean         12.86             0.07    140.99            2181.29
# std           4.23             0.05     62.28            1706.50
# min           4.56             0.00     31.29              33.29
# 25%           9.31             0.03     93.83             834.25
# 50%          12.86             0.05    143.01            1794.33
# 75%          16.00             0.09    185.64            3101.30
# max          21.35             0.33    266.89           13086.96

# %%
# Limit output to min, max, 25% and 75%
description.loc[['min','25%','75%','max']]
# Out:
#      Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# min         4.56             0.00     31.29              33.29
# 25%         9.31             0.03     93.83             834.25
# 75%        16.00             0.09    185.64            3101.30
# max        21.35             0.33    266.89           13086.96

# %%
# Checking 'Item_Outlet_Sales' values sorted by descending
df['Item_Outlet_Sales'].sort_values(ascending=False)
# Out:
# 7188    13086.9648
# 5223    12117.5600
# 1450    11445.1020
# 4349    10993.6896
# 6541    10306.5840
#            ...
# 7388       35.2874
# 3053       34.6216
# 2571       33.9558
# 6950       33.2900
# 906        33.2900
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %% [markdown]
# No inconsistencies or impossible values in numeric variables

# %%
# Check the cleaned dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   object
#  7   Outlet_Size                8523 non-null   object
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 732.6+ KB

# %% [markdown]
# * Separate your data into the feature matrix (X) and the target vector (y)

# %%
# Arrange Data into Features Matrix and Target Vector
# Assign the target column to y
y = df['Item_Outlet_Sales']
# Assign the features to X (In this case we include all columns except the target column)
X = df.drop(columns = 'Item_Outlet_Sales')

# %% [markdown]
# * Train/test split the data

# %%
# Split training and test, set random_state to 42 for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Showing X_train
X_train.head()
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  Item_MRP  \
# 4776       16.350              Low         0.029565        Others  256.4646
# 7510       15.250          Regular         0.000000   Snack Foods  179.7660
# 5828       12.350          Regular         0.158716          Meat  157.2946
# 5327        7.975              Low         0.014628  Baking Goods   82.3250
# 4810       19.350              Low         0.016645  Frozen Foods  120.9098
#
#      Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 4776            OUT018                      2009      Medium
# 7510            OUT018                      2009      Medium
# 5828            OUT049                      1999      Medium
# 5327            OUT035                      2004       Small
# 4810            OUT045                      2002      Medium
#
#      Outlet_Location_Type        Outlet_Type
# 4776               Tier 3  Supermarket Type2
# 7510               Tier 3  Supermarket Type2
# 5828               Tier 1  Supermarket Type1
# 5327               Tier 2  Supermarket Type1
# 4810               Tier 2  Supermarket Type1

# %% [markdown]
# * Create a ColumnTransformer for Preprocessing

# %%
# PREPROCESSING PIPELINE FOR NUMERIC DATA
# Create the preprocessing pipeline for numeric data
num_selector = make_column_selector(dtype_include='number')
mean_imputer = SimpleImputer(strategy='mean')
scaler = StandardScaler()
num_pipe = make_pipeline(mean_imputer, scaler)
# Make the tuple for ColumnTransformer
num_tuple = ('numeric', num_pipe, num_selector)
num_tuple
# Out:
# ('numeric',
#  Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                  ('standardscaler', StandardScaler())]),
#  <sklearn.compose._column_transformer.make_column_selector at 0x7a094db43e80>)

# %%
num_selector(X_train)
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP']

# %%
# PREPROCESSING PIPELINE FOR ORDINAL DATA
# Save list of column names
ord_cols = ['Outlet_Size']
print("Ordinal Columns:", ord_cols)
# Create imputer for ordinal data
const_imputer = SimpleImputer(strategy='constant')
## Making the OrdinalEncoder
# Specifying order of categories for our Ordinal Columm
ord_order = ['High','Medium', 'Small']
# Making the list of order lists for OrdinalEncoder
ordinal_category_orders = [ord_order]
ord_encoder = OrdinalEncoder(categories=ordinal_category_orders)
# Making a final scaler to scale category #'s
scaler_ord = StandardScaler()
## Making an ord_pipe
ord_pipe = make_pipeline(const_imputer, ord_encoder, scaler_ord)
ord_pipe
## Make a tuple for ColumnTransformer
ord_tuple = ('ordinal', ord_pipe, ord_cols)
ord_tuple
# Out:
# Ordinal Columns: ['Outlet_Size']
# ('ordinal',
#  Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='constant')),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories=[['High', 'Medium', 'Small']])),
#                  ('standardscaler', StandardScaler())]),
#  ['Outlet_Size'])

# %%
# PREPROCESSING PIPELINE FOR NOMINAL DATA
# Save list of column names
ohe_cols = X_train.select_dtypes('object').drop(columns=ord_cols).columns
print("Nominal Columns:", ohe_cols)
# Create imputer for nominal data
const_imputer = SimpleImputer(strategy='constant')
## Making the OneHotEncoder
ohe_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
## Making an ohe_pipe
ohe_pipe = make_pipeline(const_imputer, ohe_encoder)
ohe_pipe
## Make a tuple for ColumnTransformer
ohe_tuple = ('nominal', ohe_pipe, ohe_cols)
ohe_tuple
# Out:
# Nominal Columns: Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')
# ('nominal',
#  Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='constant')),
#                  ('onehotencoder',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#         'Outlet_Establishment_Year', 'Outlet_Location_Type', 'Outlet_Type'],
#        dtype='object'))

# %%
# Instantiate the make column transformer
preprocessor = ColumnTransformer([num_tuple, ord_tuple, ohe_tuple],
                                 verbose_feature_names_out=False)

# %%
# Fit the preprocessor on Training Data Only
X_train_processed = preprocessor.fit(X_train)
X_train_processed
# Out:
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7a094db43e80>),
#                                 ('ordinal',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='constant')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['High',
#                                                                               'Med...
#                                  ['Outlet_Size']),
#                                 ('nominal',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object'))],
#                   verbose_feature_names_out=False)

# %%
# Transform the training data
X_train_transformed = preprocessor.transform(X_train)
# Transform the testing data
X_test_transformed = preprocessor.transform(X_test)
# View the processed training data
X_train_transformed.head()
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Size  \
# 4776     0.819191        -0.712775  1.828109    -0.287374
# 7510     0.558284        -1.291052  0.603369    -0.287374
# 5828    -0.129561         1.813319  0.244541    -0.287374
# 5327    -1.167259        -1.004931 -0.952591     1.384048
# 4810     1.530755        -0.965484 -0.336460    -0.287374
#
#       Item_Fat_Content_Low  Item_Fat_Content_Regular  Item_Type_Baking Goods  \
# 4776                   1.0                       0.0                     0.0
# 7510                   0.0                       1.0                     0.0
# 5828                   0.0                       1.0                     0.0
# 5327                   1.0                       0.0                     1.0
# 4810                   1.0                       0.0                     0.0
#
#       Item_Type_Breads  Item_Type_Breakfast  Item_Type_Canned  ...  \
# 4776               0.0                  0.0               0.0  ...
# 7510               0.0                  0.0               0.0  ...
# 5828               0.0                  0.0               0.0  ...
# 5327               0.0                  0.0               0.0  ...
# 4810               0.0                  0.0               0.0  ...
#
#       Outlet_Establishment_Year_2004  Outlet_Establishment_Year_2007  \
# 4776                             0.0                             0.0
# 7510                             0.0                             0.0
# 5828                             0.0                             0.0
# 5327                             1.0                             0.0
# 4810                             0.0                             0.0
#
#       Outlet_Establishment_Year_2009  Outlet_Location_Type_Tier 1  \
# 4776                             1.0                          0.0
# 7510                             1.0                          0.0
# 5828                             0.0                          1.0
# 5327                             0.0                          0.0
# 4810                             0.0                          0.0
#
#       Outlet_Location_Type_Tier 2  Outlet_Location_Type_Tier 3  \
# 4776                          0.0                          1.0
# 7510                          0.0                          1.0
# 5828                          0.0                          0.0
# 5327                          1.0                          0.0
# 4810                          1.0                          0.0
#
#       Outlet_Type_Grocery Store  Outlet_Type_Supermarket Type1  \
# 4776                        0.0                            0.0
# 7510                        0.0                            0.0
# 5828                        0.0                            1.0
# 5327                        0.0                            1.0
# 4810                        0.0                            1.0
#
#       Outlet_Type_Supermarket Type2  Outlet_Type_Supermarket Type3
# 4776                            1.0                            0.0
# 7510                            1.0                            0.0
# 5828                            0.0                            0.0
# 5327                            0.0                            0.0
# 4810                            0.0                            0.0
#
# [5 rows x 46 columns]

# %% [markdown]
# # **FINAL PART**

# %% [markdown]
# The first project will be a sales prediction for food items sold at various stores. The goal of this is to help the retailer understand the properties of products and outlets that play crucial roles in increasing sales.

# %%
# Import all librairies
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Create a function to take the true and predicted labels and print RMSE and R2 metrics
def evaluate_model(y_true, y_pred):
  rmse = np.sqrt(mean_squared_error(y_true, y_pred))
  r2 = r2_score(y_true, y_pred)
  print(f'RMSE: {rmse:,.3f} \nR2: {r2:.3f}')

# %% [markdown]
# ## **CRISP-DM Phase 4 - Modeling**

# %% [markdown]
# ### **Linear Regression Model to predict sales**

# %%
# Run a Linear tree model
# Instantiate a linear regression model
linreg = LinearRegression()
# Combine the preprocessing ColumnTransformer and the linear regression model in a Pipeline
linreg_pipe = make_pipeline(preprocessor, linreg)
linreg_pipe
# Fit the model pipeline on the training data
linreg_pipe.fit(X_train, y_train)
# Make predictions using the training and testing data
training_pred = linreg_pipe.predict(X_train)
test_pred = linreg_pipe.predict(X_test)
training_pred[:10]
# Out:
# array([3814.25  , 2654.75  , 2607.75  , 1484.5625, 1873.0625,  -66.875 ,
#        1594.5625, 5652.375 , 4200.6875, 2046.8125])

# %%
# Evaluate Linear Regression Model
print('Training Scores for Linear Regressor Model')
evaluate_model(y_train, training_pred)
print('Testing Scores for Linear Regressor Model')
evaluate_model(y_test, test_pred)
# Out:
# Training Scores for Linear Regressor Model
# RMSE: 1,139.122
# R2: 0.562
# Testing Scores for Linear Regressor Model
# RMSE: 1,092.760
# R2: 0.567

# %% [markdown]
# > Linear Regression Model Observations :
#
# This model performs poorly on the training set and testing set regarding R2 metric, this is a case of high biais (underfit). Most likely, this data is not well suited for a Linear Model. For RMSE metric, our model is incorrect by about 1,115 thousand dollars.
# Therefore, we will explore using other model to see how it performs.

# %% [markdown]
# ### **Regression Tree Model to predict sales**

# %%
# Run a decision tree model with default parameters (unlimited depth)
# Instatiate decision tree model
decreg = DecisionTreeRegressor(random_state=42)
# Combine the preprocessing ColumnTransformer and the decision tree model in a Pipeline
dec_tree_pipe = make_pipeline(preprocessor, decreg)
# Fit the model pipeline on the training data
dec_tree_pipe.fit(X_train, y_train)
# Make predictions for training & testing data
train_pred = dec_tree_pipe.predict(X_train)
test_pred = dec_tree_pipe.predict(X_test)
training_pred[:10]
# Out:
# array([3814.25  , 2654.75  , 2607.75  , 1484.5625, 1873.0625,  -66.875 ,
#        1594.5625, 5652.375 , 4200.6875, 2046.8125])

# %%
# Evaluate Decision Tree Model
print('Training Scores for Decision Tree Model')
evaluate_model(y_train, train_pred)
print('Testing Scores for Decision Tree Model')
evaluate_model(y_test, test_pred)
# Out:
# Training Scores for Decision Tree Model
# RMSE: 0.000
# R2: 1.000
# Testing Scores for Decision Tree Model
# RMSE: 1,498.803
# R2: 0.186

# %% [markdown]
# > Decision Tree Model Observations :
#
# This model performs perfect on the training data regarding R2 metric. However, it performs poorly on the testing data, this is a case of high variance (overfitting). For RMSE metric, our model is incorrect by about 1,5 thousand dollars it penalizes more larger errors than Linear model.
# This model is definitely overfit and will need tuning.

# %% [markdown]
# ## **CRISP-DM Phase 5 - Evaluation**

# %% [markdown]
# After trying 2 different models on the data set :
# * Linear Regression Model is underfitting : this model with high bias is consistently unable to make accurate predictions using any set of features, may be we should increase the complexity of the model to combat bias
# * Decision Tree Model is overfitting :  A high variance often means that we can improve your model's performance on the test set, which is most important. To combat overfitting, we should add regularization.

# %% [markdown]
# **Tunning Decision Tree Model**

# %%
# Looking at options for tuning this model
decreg.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
# Get depth & leaf nodes of tree with default model
dec_tree_pipe['decisiontreeregressor'].get_depth(), dec_tree_pipe['decisiontreeregressor'].get_n_leaves()
# Out:
# (35, 6267)

# %%
# Create a range of max_depth values
depths = range(1, 35)
# depths = range(1, dec_tree_pipe['decisiontreeregressor'].get_depth())
# Create a dataframe to store train and test scores.
scores = pd.DataFrame(index=depths, columns=['Train Score', 'Test Score'])
# Loop over the values in depths
for depth in depths:
  # Fit a new model with max_depth
  dec_tree = DecisionTreeRegressor(max_depth=depth, random_state = 42)
  # Put the model into a pipeline
  tree_pipe = make_pipeline(preprocessor, dec_tree)
  # Fit the model
  tree_pipe.fit(X_train, y_train)
  # Create prediction arrays
  train_pred = tree_pipe.predict(X_train)
  test_pred = tree_pipe.predict(X_test)
  # Calculate score
  train_score = r2_score(y_train, train_pred)
  test_score = r2_score(y_test, test_pred)
  # Store the scores in the scores dataframe
  scores.loc[depth, 'Train Score'] = train_score
  scores.loc[depth, 'Test Score'] = test_score
# View first 5 rows of score dataframe
scores.head()
# Out:
#   Train Score Test Score
# 1    0.237797   0.229683
# 2    0.431641   0.433778
# 3    0.524218   0.524222
# 4    0.582625   0.584005
# 5     0.60394    0.59471

# %%
# Visualize which max_depth leads to the highest r2 score
plt.plot(depths, scores['Test Score'], label = 'Test')
plt.xlabel('Max Depths')
plt.ylabel('R2 Score')
plt.legend()
plt.grid()

# %%
#sort the dataframe by test scores and save the index of the best score
best_depth = scores.sort_values(by='Test Score', ascending=False).index[0]
best_depth
# Out:
# 5

# %%
# Sort by best result on test data
sorted_scores = scores.sort_values(by='Test Score', ascending=False)
sorted_scores.head()
# Out:
#   Train Score Test Score
# 5     0.60394    0.59471
# 4    0.582625   0.584005
# 6    0.615161   0.582273
# 7    0.626821   0.578495
# 8    0.643779   0.564311

# %% [markdown]
# **The best hyperparameter for the tuned Decision Tree Model**

# %%
# Let's run the model with our optimized value for max_depth
dec_tree_b = DecisionTreeRegressor(max_depth = best_depth, random_state = 42)
# Put the model into a pipeline
tree_pipe_b = make_pipeline(preprocessor, dec_tree_b)
# Fit on the training data
tree_pipe_b.fit(X_train, y_train)
# Get predictions
train_pred = tree_pipe_b.predict(X_train)
test_pred = tree_pipe_b.predict(X_test)
# Calculate score
train_score = r2_score(y_train, train_pred)
test_score = r2_score(y_test, test_pred)

# %%
# Evaluate Decision Tree Model
print('Training Scores for Decision Tree Model')
evaluate_model(y_train, train_pred)
print('Testing Scores for Decision Tree Model')
evaluate_model(y_test, test_pred)
# Out:
# Training Scores for Decision Tree Model
# RMSE: 1,082.646
# R2: 0.604
# Testing Scores for Decision Tree Model
# RMSE: 1,057.443
# R2: 0.595

# %% [markdown]
# By getting the best hyperparameter (max_depth=5), the R2 testing score become  higher, it grows to 0.595 after tuning. The training (0.604) and test (0.595) results have moved closer to each other. The RMSE score is reduced, this model  is incorrect by an average of 1,07 thousand dollars.
# By tunning the decision tree model we have reduced overfitting and RMSE metric. This model still has high bias even after tuning the max depth. We will try other improved regression trees and find a good balance between variance and biais.
